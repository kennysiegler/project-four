# %%
import yfinance as yf
import pandas as pd
import datetime as dt
from datetime import timedelta
import pandas_ta as ta

from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
start = start = dt.datetime(1999,1,1)
end = dt.datetime.now()
days = 14
ticker = 'SPY'

# %%
df = yf.download(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-01-04  123.375000  125.218750  121.718750  123.031250   79.169899
# 1999-01-05  122.937500  124.875000  122.937500  124.437500   80.074806
# 1999-01-06  125.812500  127.750000  125.750000  127.437500   82.005295
# 1999-01-07  126.375000  127.218750  125.781250  126.812500   81.603119
# 1999-01-08  128.187500  128.500000  125.968750  127.750000   82.206413
# ...                ...         ...         ...         ...         ...
# 2023-08-18  433.369995  437.570007  433.010010  436.500000  436.500000
# 2023-08-21  437.549988  440.109985  435.320007  439.339996  439.339996
# 2023-08-22  441.179993  441.179993  437.570007  438.149994  438.149994
# 2023-08-23  439.250000  443.670013  439.100006  443.029999  443.029999
# 2023-08-24  444.690002  445.220001  436.859985  436.890015  436.890015
#
#               Volume
# Date
# 1999-01-04   9450400
# 1999-01-05   8031000
# 1999-01-06   7737700
# 1999-01-07   5504900
# 1999-01-08   6224400
# ...              ...
# 2023-08-18  98758400
# 2023-08-21  68719000
# 2023-08-22  65062900
# 2023-08-23  68441000
# 2023-08-24  88379900
#
# [6201 rows x 6 columns]

# %%
del df['Adj Close']

df['Range'] = abs(df['High']-df['Low'])
df['RSI 14'] = ta.rsi(df['Close'], 14)
df['SMA 20'] = ta.sma(df['Close'], 20)
df['SMA 50'] = ta.sma(df['Close'], 50)

# %%
df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 1999-01-04  123.375000  125.218750  121.718750  123.031250   9450400
# 1999-01-05  122.937500  124.875000  122.937500  124.437500   8031000
# 1999-01-06  125.812500  127.750000  125.750000  127.437500   7737700
# 1999-01-07  126.375000  127.218750  125.781250  126.812500   5504900
# 1999-01-08  128.187500  128.500000  125.968750  127.750000   6224400
# ...                ...         ...         ...         ...       ...
# 2023-08-18  433.369995  437.570007  433.010010  436.500000  98758400
# 2023-08-21  437.549988  440.109985  435.320007  439.339996  68719000
# 2023-08-22  441.179993  441.179993  437.570007  438.149994  65062900
# 2023-08-23  439.250000  443.670013  439.100006  443.029999  68441000
# 2023-08-24  444.690002  445.220001  436.859985  436.890015  88379900
#
#                Range     RSI 14      SMA 20      SMA 50
# Date
# 1999-01-04  3.500000        NaN         NaN         NaN
# 1999-01-05  1.937500        NaN         NaN         NaN
# 1999-01-06  2.000000        NaN         NaN         NaN
# 1999-01-07  1.437500        NaN         NaN         NaN
# 1999-01-08  2.531250        NaN         NaN         NaN
# ...              ...        ...         ...         ...
# 2023-08-18  4.559998  35.283750  448.740503  444.149401
# 2023-08-22  441.179993  441.179993  437.570007  438.149994  65062900
# 2023-08-23  439.250000  443.670013  439.100006  443.029999  68441000
# 2023-08-24  444.690002  445.220001  436.859985  436.890015  88379900
#
#                Range     RSI 14      SMA 20      SMA 50    Tomorrow  Target
# Date
# 2000-01-03  4.375000  60.123229  143.598437  140.252500  139.750000       0
# 2000-01-04  4.421875  39.912317  143.446875  140.445625  140.000000       1
# 2000-01-05  4.281250  40.853504  143.365625  140.656875  137.750000       0
# 2000-01-06  3.750000  35.468775  143.217187  140.855625  145.750000       1
# 2000-01-07  5.687500  57.113342  143.434375  141.168125  146.250000       1
# ...              ...        ...         ...         ...         ...     ...
# 2023-08-18  4.559998  35.283750  448.740503  444.149401  439.339996       1
# 2023-08-21  4.789978  40.887683  447.997502  444.353600  438.149994       0
# 2023-08-22  3.609985  39.350095  447.133002  444.518600  443.029999       1
# 2023-08-23  4.570007  47.987997  446.509001  444.703201  436.890015       0
# 2023-08-24  8.360016  40.225352  445.729002  444.707801         NaN       0
#
# [5949 rows x 11 columns]

# %%
# loop through dataframe and add all features to a list
# removes 'Tomorrow' and 'Target' column from the list 
def get_features(dataframe):
    features = []
    for column in dataframe:
        features.append(column)
    
    features.pop(-1)
    features.pop(-1)
    
    return features

# %%
features = get_features(df)

# %%
# n_estimators = number of decision trees
# min_samples_split = higher it is set, the less accurtate it is, the less it will overfit
model = RandomForestClassifier(n_estimators=300, min_samples_split=100, random_state=1)

train = df.iloc[:-100]
test = df.iloc[-100:]


model.fit(train[features], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=300, random_state=1)

# %%
predictions = model.predict(test[features])

# %%
predictions_series = pd.Series(predictions, index=test.index)
predictions_series
# Out:
# Date
# 2023-04-03    1
# 2023-04-04    0
# 2023-04-05    1
# 2023-04-06    1
# 2023-04-10    1
#              ..
# 2023-08-18    1
# 2023-08-21    1
# 2023-08-22    1
# 2023-08-23    1
# 2023-08-24    1
# Length: 100, dtype: int32

# %%
# check precision of testing data
precision_score(test['Target'], predictions)
# Out:
# 0.5098039215686274

# %%
combined = pd.concat([test['Target'], predictions_series], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
print("Classification Report")
print(classification_report(test['Target'], predictions))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.45      0.47      0.46        47
#            1       0.51      0.49      0.50        53
#
#     accuracy                           0.48       100
#    macro avg       0.48      0.48      0.48       100
# weighted avg       0.48      0.48      0.48       100

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.09528792, 0.09100081, 0.09152388, 0.09351209, 0.15133928,
#        0.12926525, 0.14529617, 0.09807038, 0.10470423])

# %%
# check precision of training data

# %%
predictions_training = model.predict(train[features])

# %%
precision_score(train['Target'], predictions_training)
# Out:
# 0.7231825114387392
